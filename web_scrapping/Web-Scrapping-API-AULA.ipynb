# %% [markdown]
# # Web Scrapping using an API

# %% [markdown]
# ### A set of functions and procedures allowing the creation of applications that access the features or data of an operating system, application, or other service.

# %% [markdown]
# ![API.png](attachment:API.png)

# %%
# %%html
# <iframe src="https://jrderuiter.github.io/pybiomart/api.html" width="1200" height="1000"></iframe>
# Out:
# <iframe src="https://jrderuiter.github.io/pybiomart/api.html" width="1200" height="1000"></iframe>

# %% [markdown]
# ### Install API libraries on jupyter
# #### (If you are writing your code directly on a .py file you can use pip install instead)
