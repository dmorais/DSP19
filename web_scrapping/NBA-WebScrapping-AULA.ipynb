# %% [markdown]
# ## Web Scrapping with Python
#
# Web harvesting, or web data extraction is data scraping used for extracting data from websites.
#
# In this Class we will learn how to extract data from websites and import them into our applications.

# %% [markdown]
# ### First we will learn about the HTML structure

# %%
# %%html
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title>Transcripts</title>
# </head>
#     <body>
#         <div class="container">
#             <h1>Table of transcripts</h1>
#         </div>
#
#         <div class="container">
#             <div class="jumbotron">
#                 <table class="table">
#                     <tr>
#                         <th>Transcript</th>
#                         <th>p-value</th>
#                         <th>GO</th>
#                     </tr>
#                     <tr>
#                         <td>tr|0001|</td>
#                         <td>0.0001</td>
#                         <td>GO:000999</td>
#                     </tr>
#                     <tr>
#                         <td>tr|0002|</td>
#                         <td>0.5</td>
#                         <td>GO:09098</td>
#                     </tr>
#                 </table>
#
#             </div>
#         </div>
#
#     </body>
# </html>

# %% [markdown]
# ### Let's suppose we would like to make a study about NBA player but don't have the data available to do so.
#
# 1. The First step is to find a website where the data can be extracted from
# 2. Investigate the HTML structure of the site
# 3. Have fun !!!!

# %% [markdown]
# ### A famous website for NBS stats is the Baskteball reference
# ##### https://www.basketball-reference.com/
#
# This site contains stat of all players and seasons, perfect for what we want

# %% [markdown]
# For this part, I used the individual per game stats of players for the current 2018–2019 NBA season. The page on Basketball Reference looks like this
#
# ![nba-table1.png](attachment:nba-table1.png)

# %% [markdown]
# 1. Next step is to inspect the html itself
# 2. From a Firefox go to https://www.basketball-reference.com/leagues/NBA_2019_per_game.html
# 3. Now right-click on the table and select **inspect Element**
# 4. As you can see the table is similar to the simple example above
